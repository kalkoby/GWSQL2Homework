# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
conn = engine.connect()
test = pd.read_sql("Select * from Measurement",conn)
test.head()
# Out:
#    id      station        date  prcp  tobs
# 0   1  USC00519397  2010-01-01  0.08  65.0
# 1   2  USC00519397  2010-01-02  0.00  63.0
# 2   3  USC00519397  2010-01-03  0.00  74.0
# 3   4  USC00519397  2010-01-04  0.00  76.0
# 4   5  USC00519397  2010-01-06   NaN  73.0

# %% [markdown]
# # Precipitation Analysis
# * Design a query to retrieve the last 12 months of precipitation data and plot the results

# %%
# Calculate the date 1 year ago from the last data point in the database
last_date_found = session.query(Measurement.date).order_by(Measurement.date.desc()).first()
last_date_found
# Out:
# ('2017-08-23')

# %%
# Perform a query to retrieve the data and precipitation scores
last_12_months = session.query(Measurement.date,Measurement.prcp).\
                 filter(Measurement.date >= '2016-08-24').filter(Measurement.date <= '2017-08-23').\
                        order_by(Measurement.date).all()
last_12_months
# Out:
# [('2016-08-24', 0.08),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 2.28),
#  ('2016-08-24', None),
#  ('2016-08-24', 1.22),
#  ('2016-08-24', 2.15),
#  ('2016-08-24', 1.45),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.0),
#  ('2016-08-25', 0.21),
#  ('2016-08-25', 0.06),
#  ('2016-08-25', 0.11),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.03),
#  ('2016-08-26', 0.02),
#  ('2016-08-26', 0.04),
#  ('2016-08-26', 0.0),
#  ('2016-08-26', 0.01),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.18),
#  ('2016-08-27', 0.02),
#  ('2016-08-27', 0.0),
#  ('2016-08-27', 0.12),
#  ('2016-08-27', None),
#  ('2016-08-28', 0.01),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.14),
#  ('2016-08-28', 0.6),
#  ('2016-08-28', 2.07),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.17),
#  ('2016-08-29', 0.04),
#  ('2016-08-29', None),
#  ('2016-08-29', 0.0),
#  ('2016-08-29', 0.35),
#  ('2016-08-29', 0.9),
#  ('2016-08-30', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
results_last_12months_df = pd.DataFrame(last_12_months,columns=['date','precipitation'])
results_last_12months_df.set_index('date')
# Out:
#             precipitation
# date
# 2016-08-24           0.08
# 2016-08-24           2.15
# 2016-08-24           2.28
# 2016-08-24            NaN
# 2016-08-24           1.22
# 2016-08-24           2.15
# 2016-08-24           1.45
# 2016-08-25           0.08
# 2016-08-25           0.08
# 2016-08-25           0.00
# 2016-08-25           0.00
# 2016-08-25           0.21
# 2016-08-25           0.06
# 2016-08-25           0.11
# 2016-08-26           0.00
# 2016-08-26           0.03
# 2016-08-26           0.02
# 2016-08-26           0.04
# 2016-08-26           0.00
# 2016-08-26           0.01
# 2016-08-27           0.00
# 2016-08-27           0.18
# 2016-08-27           0.02
# 2016-08-27           0.00
# 2016-08-27           0.12
# 2016-08-27            NaN
# 2016-08-28           0.01
# 2016-08-28           0.14
# 2016-08-28           0.14
# 2016-08-28           0.14
# ...                   ...
# 2017-08-16           0.00
# 2017-08-16           0.07
# 2017-08-16           0.12
# ...

# %%
# Sort the dataframe by date
results_last_12months_df.sort_values(by=['date'])
results_last_12months_df.head()
# Out:
#          date  precipitation
# 0  2016-08-24           0.08
# 1  2016-08-24           2.15
# 2  2016-08-24           2.28
# 3  2016-08-24            NaN
# 4  2016-08-24           1.22

# %%
# Use Pandas Plotting with Matplotlib to plot the data

results_last_12months_df.plot(figsize=(10,10))

plt.ylabel("Precipitation")
plt.xlabel("date")

#turn off tick labelsdata:image/png;base64,...
plt.xticks([])

plt.tight_layout()
plt.savefig("Images/Precipitation.png")
plt.show()

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
results_last_12months_df.describe()
# Out:
#        precipitation
# count    2015.000000
# mean        0.176462
# std         0.460288
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# Design a query to show how many stations are available in this dataset?
stations_count = session.query(Station.id).count()
stations_count
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
session.query(Measurement.station, func.count(Measurement.station)).\
        group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?

session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
             filter(Measurement.station == 'USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
highTemp = session.query(Measurement.tobs). \
    filter(Measurement.station == 'USC00519281').\
    filter(Measurement.date >= '2016-08-23').all()

station_hightemp = pd.DataFrame(highTemp,columns=['tobs'])
station_hightemp.plot.hist(bins=12,figsize=(10,10))
plt.tight_layout()
plt.savefig("Images/HighestTemp.png")
plt.show()

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
start_trip = dt.date(2016,8,28)
end_trip = dt.date(2016,9,1)

prev_yr_startTrip = start_trip - dt.timedelta(days=365)
prev_yr_endTrip = end_trip - dt.timedelta(days=365)

trip_temps = calc_temps(prev_yr_startTrip, prev_yr_endTrip)
trip_temps
# Out:
# [(73.0, 79.39393939393939, 85.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-p,eak (tmax-tmin) value as the y error bar (yerr)


fig, ax = plt.subplots(figsize=plt.figaspect(2.))
avg_temp = trip_temps[0][1]
xpos = 1
error = trip_temps[0][2] - trip_temps[0][1]
bar = ax.bar(xpos,avg_temp, yerr=error, alpha=0.5,color='green',align='center')
ax.set(xticks=range(xpos),xticklabels="a",title="Trip Avg Temp",ylabel="Average Temperature (F)")
ax.margins(.2,.2)

fig.tight_layout()
plt.savefig("Images/TripAvgTemp.png")
fig.show
# Out:
# <bound method Figure.show of <Figure size 288x576 with 1 Axes>>

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation
rainfall = [Station.station,Station.name,Station.latitude,Station.longitude,Station.elevation,func.sum(Measurement.prcp)]

resultRainfall = session.query(*rainfall).\
   filter(Measurement.station == Station.station). \
   filter(Measurement.date >= start_trip). \
   filter(Measurement.date <= end_trip). \
   group_by(Station.name).order_by(func.sum(Measurement.prcp).desc()).all()

print(resultRainfall)
# Out:
# [('USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4, 5.489999999999999), ('USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9, 1.21), ('USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6, 0.41000000000000003), ('USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5, 0.39), ('USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0, 0.18000000000000002), ('USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0, 0.14), ('USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9, 0.02)]

# %% [markdown]
# # Completed the Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# similiar to above function but it contains the start date and end date for range of trip dates
# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

def daily_normals(start_date,end_date):
    """Start date of Daily Normals.
       End date of Daily Normals
    
    Args:
        start_date (str): A date string in the format '%m-%d'
        end_date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    """
    
    sel = [func.strftime("%m-%d",Measurement.date),func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) >= start_date). \
           filter(func.strftime("%m-%d",Measurement.date) <= end_date).group_by(func.strftime("%m-%d",Measurement.date)).all()
   
    
results = daily_normals("01-01","01-15")
results
# Out:
# [('01-01', 62.0, 69.15384615384616, 77.0),
#  ('01-02', 60.0, 69.39622641509433, 77.0),
#  ('01-03', 62.0, 68.9090909090909, 77.0),
#  ('01-04', 58.0, 70.0, 76.0),
#  ('01-05', 56.0, 67.96428571428571, 76.0),
#  ('01-06', 61.0, 68.96491228070175, 76.0),
#  ('01-07', 57.0, 68.54385964912281, 76.0),
#  ('01-08', 57.0, 67.16071428571429, 75.0),
#  ('01-09', 58.0, 67.9298245614035, 78.0),
#  ('01-10', 62.0, 69.74137931034483, 77.0),
#  ('01-11', 57.0, 67.3103448275862, 78.0),
#  ('01-12', 57.0, 67.4074074074074, 81.0),
#  ('01-13', 57.0, 67.25454545454545, 77.0),
#  ('01-14', 58.0, 69.52631578947368, 77.0),
#  ('01-15', 56.0, 69.31372549019608, 78.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

daily_normals_df = pd.DataFrame(results,columns=['date','tmin','tavg','tmax'])

daily_normals_df.set_index('date',inplace=True)
daily_normals_df
# Out:
#        tmin       tavg  tmax
# date
# 01-01  62.0  69.153846  77.0
# 01-02  60.0  69.396226  77.0
# 01-03  62.0  68.909091  77.0
# 01-04  58.0  70.000000  76.0
# 01-05  56.0  67.964286  76.0
# 01-06  61.0  68.964912  76.0
# 01-07  57.0  68.543860  76.0
# 01-08  57.0  67.160714  75.0
# 01-09  58.0  67.929825  78.0
# 01-10  62.0  69.741379  77.0
# 01-11  57.0  67.310345  78.0
# 01-12  57.0  67.407407  81.0
# 01-13  57.0  67.254545  77.0
# 01-14  58.0  69.526316  77.0
# 01-15  56.0  69.313725  78.0

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
daily_normals_df.plot(kind='area',alpha=.3,stacked=False,title="Aggregate Daily Normals for Trip Dates",figsize=(10,10))
plt.tight_layout()
plt.savefig("Images/Normals.png")
plt.show()
